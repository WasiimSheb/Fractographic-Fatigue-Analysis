# %%
import os
from keras.models import load_model

# Input directory containing the images
input_dir ="C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\EBM6-TI-6AL-4V-SEM" # change the path to the image
# Model paths
ext_model_path = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\models\\external_mask_unet_model.h5" # change the path to the model
int_model_path = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\models\\internal_smaller_mask_unet_model.h5" # change the path to the model

# %%
from PIL import Image

# Iterate through the directory
for filename in os.listdir(input_dir):
    if filename.endswith('.tif'):  # Check for TIFF images
        image_path = os.path.join(input_dir, filename)  # Full path to image
        im = Image.open(image_path)
        png_path = image_path[:-3] + 'png'  # Replace .tif with .png
        im.save(png_path)  # Save as PNG
        print(f"Converted: {filename} -> {os.path.basename(png_path)}")
# Out:
# Converted: C14-1.5_C_01 (1).tif -> C14-1.5_C_01 (1).png
# Converted: C14_1.5_N_01 (1).tif -> C14_1.5_N_01 (1).png
# Converted: C14_5.7_C_01 (1).tif -> C14_5.7_C_01 (1).png
# Converted: C14_5.7_N_01 (1).tif -> C14_5.7_N_01 (1).png
# Converted: C14_5.7_N_02 (1).tif -> C14_5.7_N_02 (1).png
# Converted: C15_3.5_C_01 (1).tif -> C15_3.5_C_01 (1).png
# Converted: C15_3.5_C_01.tif -> C15_3.5_C_01.png
# Converted: C15_3.5_N_01 (1).tif -> C15_3.5_N_01 (1).png
# Converted: C15_4.8_C_01 (1).tif -> C15_4.8_C_01 (1).png
# Converted: C15_4.8_N_01 (1).tif -> C15_4.8_N_01 (1).png
# Converted: C15_8.6_C_01.tif -> C15_8.6_C_01.png
# Converted: C15_8.6_N_01 (1).tif -> C15_8.6_N_01 (1).png
# Converted: C15_8.6_N_01.tif -> C15_8.6_N_01.png
# Converted: C15_8.8_C_01 (1).tif -> C15_8.8_C_01 (1).png
# Converted: C15_8.8_N_01 (1).tif -> C15_8.8_N_01 (1).png
# Converted: C15_9.5_C_01 (1).tif -> C15_9.5_C_01 (1).png
# Converted: C15_9.5_C_01.tif -> C15_9.5_C_01.png
# Converted: C15_9.5_N_01 (1).tif -> C15_9.5_N_01 (1).png
# Converted: C15_9.5_N_02 (1).tif -> C15_9.5_N_02 (1).png
# Converted: C16_10.2_C_01.tif -> C16_10.2_C_01.png
# Converted: C16_10.2_N_01.tif -> C16_10.2_N_01.png
# Converted: C16_10.2_N_02.tif -> C16_10.2_N_02.png
# Converted: C16_7.5_C_01.tif -> C16_7.5_C_01.png
# Converted: C16_7.5_N_01.tif -> C16_7.5_N_01.png
# Converted: C16_7.7_C_01.tif -> C16_7.7_C_01.png
# Converted: C16_7.7_N.tif -> C16_7.7_N.png
# Converted: C16_7.9_C_01.tif -> C16_7.9_C_01.png
# Converted: C16_7.9_N_01.tif -> C16_7.9_N_01.png
# Converted: C16_8.4_C_01.tif -> C16_8.4_C_01.png
# Converted: C16_8.4_N_01.tif -> C16_8.4_N_01.png

# %%
import cv2
import os

# Iterate through all images in the directory
for filename in os.listdir(input_dir):
    if filename.endswith('.png'):  # Process only PNG files
        image_path = os.path.join(input_dir, filename)
        
        # Load the image
        img = cv2.imread(image_path)
        
        # Convert to grayscale and get dimensions
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, width = gray.shape
        
        # Crop to a square
        img = img[0:width, 0:width]
        
        # Replace the image with the new cropped version
        cv2.imwrite(image_path, img)
        print(f"Cropped and replaced: {filename}")
# Out:
# Cropped and replaced: C14-1.5_C_01 (1).png
# Cropped and replaced: C14_1.5_N_01 (1).png
# Cropped and replaced: C14_5.7_C_01 (1).png
# Cropped and replaced: C14_5.7_N_01 (1).png
# Cropped and replaced: C14_5.7_N_02 (1).png
# Cropped and replaced: C15_3.5_C_01 (1).png
# Cropped and replaced: C15_3.5_C_01.png
# Cropped and replaced: C15_3.5_N_01 (1).png
# Cropped and replaced: C15_4.8_C_01 (1).png
# Cropped and replaced: C15_4.8_N_01 (1).png
# Cropped and replaced: C15_8.6_C_01.png
# Cropped and replaced: C15_8.6_N_01 (1).png
# Cropped and replaced: C15_8.6_N_01.png
# Cropped and replaced: C15_8.8_C_01 (1).png
# Cropped and replaced: C15_8.8_N_01 (1).png
# Cropped and replaced: C15_9.5_C_01 (1).png
# Cropped and replaced: C15_9.5_C_01.png
# Cropped and replaced: C15_9.5_N_01 (1).png
# Cropped and replaced: C15_9.5_N_02 (1).png
# Cropped and replaced: C16_10.2_C_01.png
# Cropped and replaced: C16_10.2_N_01.png
# Cropped and replaced: C16_10.2_N_02.png
# Cropped and replaced: C16_7.5_C_01.png
# Cropped and replaced: C16_7.5_N_01.png
# Cropped and replaced: C16_7.7_C_01.png
# Cropped and replaced: C16_7.7_N.png
# Cropped and replaced: C16_7.9_C_01.png
# Cropped and replaced: C16_7.9_N_01.png
# Cropped and replaced: C16_8.4_C_01.png
# Cropped and replaced: C16_8.4_N_01.png

# %%
#Alumunium:
# import os
# import cv2
# import numpy as np

# def get_largest_contour(mask: np.ndarray, min_area: int = 10000):
#     """
#     Extracts the largest contour from the given binary mask and filters out small irrelevant contours.
#     Adjusting contour selection to be more adaptive to the shape.
#     """
#     ret, thresh = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
#     contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     largest_contour = None
#     if contours:
#         # Filter contours based on area and shape (aspect ratio, circularity)
#         valid_contours = [c for c in contours if cv2.contourArea(c) > min_area]
#         if valid_contours:
#             largest_contour = max(valid_contours, key=cv2.contourArea)
#     return largest_contour

# def refine_mask(mask: np.ndarray, contour: np.ndarray):
#     """
#     Refines the mask based on the largest contour, with less aggressive morphological operations.
#     """
#     refined_mask = np.zeros_like(mask)
#     if contour is not None:
#         # Draw the largest contour, keeping all the areas inside it
#         cv2.drawContours(refined_mask, [contour], -1, 255, thickness=-1)
    
#     # Less aggressive morphological operations to clean noise, keeping more of the shape
#     kernel = np.ones((5, 5), np.uint8)
#     refined_mask = cv2.morphologyEx(refined_mask, cv2.MORPH_OPEN, kernel, iterations=1)
#     refined_mask = cv2.morphologyEx(refined_mask, cv2.MORPH_CLOSE, kernel, iterations=1)
    
#     return refined_mask

# def extract_mask_from_array(image_array):
#     """
#     Extracts the mask for the external contour from an image array using a CV-based approach.
#     Adjusted to work with different lighting and edge conditions.
#     """
#     if len(image_array.shape) == 3:
#         image = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
#     else:
#         image = image_array

#     # Enhance contrast using CLAHE
#     clahe = cv2.createCLAHE(clipLimit=2.5, tileGridSize=(8, 8))
#     enhanced_image = clahe.apply(image)
    
#     # Smooth the image
#     smoothed_image = cv2.GaussianBlur(enhanced_image, (5, 5), 0)
    
#     # Dynamically adjust edge detection thresholds
#     median_intensity = np.median(smoothed_image)
#     lower_threshold = int(max(0, (0.5 - 0.7) * median_intensity))  # Adjusted threshold range 0.5 or 1, 0.3-0.7
#     upper_threshold = int(min(255, (0.5 + 0.7) * median_intensity))  # More adaptive range
#     edges = cv2.Canny(smoothed_image, lower_threshold, upper_threshold)
    
#     # Dilate edges to make them more continuous
#     kernel = np.ones((3, 3), np.uint8)
#     dilated_edges = cv2.dilate(edges, kernel, iterations=2)
    
#     # Fill gaps using morphological closing
#     closed_edges = cv2.morphologyEx(dilated_edges, cv2.MORPH_CLOSE, kernel)
    
#     # Find the largest contour from the edges
#     mask = np.zeros_like(image)
#     contours, _ = cv2.findContours(closed_edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     if contours:
#         largest_contour = max(contours, key=cv2.contourArea)
#         cv2.drawContours(mask, [largest_contour], -1, 255, thickness=-1)
    
#     return mask

# def extract_segmented_inner_shape(image, mask):
#     """
#     Extracts the segmented inner shape by applying the refined mask to the original image.
#     This time, the mask is refined with less aggressive cleaning to avoid removing important parts.
#     """
#     # Refine the mask based on detected contours
#     largest_contour = get_largest_contour(mask, min_area=15000)  # Adjust min_area for better accuracy
#     refined_mask = refine_mask(mask, largest_contour)
    
#     # Apply the refined mask to the image
#     segmented_inner = np.zeros_like(image)
#     segmented_inner[refined_mask == 255] = image[refined_mask == 255]
    
#     return segmented_inner


# # Input and output directories
# input_dir ="C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\Al-NEW-part1"
# mask_output_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\Al-NEW part1-masks"
# segmented_inner_output_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\Al-NEW part1-segmented_inner_Shape"
# os.makedirs(mask_output_dir, exist_ok=True)
# os.makedirs(segmented_inner_output_dir, exist_ok=True)

# # Process images
# for filename in os.listdir(input_dir):
#     if filename.endswith('.png'):
#         image_path = os.path.join(input_dir, filename)
#         print(f"Processing {filename}...")

#         img = cv2.imread(image_path)

#         # Extract the mask
#         mask = extract_mask_from_array(img)

#         # Extract and save the segmented inner shape
#         segmented_inner = extract_segmented_inner_shape(img, mask)
#         segmented_inner_path = os.path.join(segmented_inner_output_dir, f"{os.path.splitext(filename)[0]}_segmented_inner.png")
#         cv2.imwrite(segmented_inner_path, segmented_inner)

#         # Save the binary mask image (just the mask)
#         mask_path = os.path.join(mask_output_dir, f"{os.path.splitext(filename)[0]}_mask.png")
#         cv2.imwrite(mask_path, mask)

#         print(f"Completed processing for {filename}")

#=========================================================================
#Alumunium part 2
# import os
# import cv2
# import numpy as np

# def get_largest_contour(mask: np.ndarray, min_area: int = 10000):
#     """
#     Extracts the largest contour from the given binary mask and filters out small irrelevant contours.
#     """
#     ret, thresh = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
#     contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     largest_contour = None
#     if contours:
#         # Filter contours based on area
#         valid_contours = [c for c in contours if cv2.contourArea(c) > min_area]
#         if valid_contours:
#             largest_contour = max(valid_contours, key=cv2.contourArea)
#     return largest_contour

# def refine_mask(mask: np.ndarray, contour: np.ndarray, center: tuple, radius: int):
#     """
#     Refines the mask by keeping only the region inside the largest contour
#     and applying a stricter circular constraint.
#     """
#     refined_mask = np.zeros_like(mask)
#     if contour is not None:
#         # Draw the largest contour
#         cv2.drawContours(refined_mask, [contour], -1, 255, thickness=-1)
#         # Create a stricter circular mask
#         circular_mask = np.zeros_like(mask)
#         cv2.circle(circular_mask, center, radius, 255, thickness=-1)
#         # Combine the two masks
#         refined_mask = cv2.bitwise_and(refined_mask, circular_mask)
    
#     # Aggressive morphological operations to clean noise
#     kernel = np.ones((3, 3), np.uint8)
#     refined_mask = cv2.morphologyEx(refined_mask, cv2.MORPH_OPEN, kernel, iterations=3)
#     refined_mask = cv2.morphologyEx(refined_mask, cv2.MORPH_CLOSE, kernel, iterations=3)
    
#     return refined_mask

# def extract_mask_from_array(image_array):
#     """
#     Extracts the mask for the external contour from an image array using a CV-based approach.
#     """
#     if len(image_array.shape) == 3:
#         image = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
#     else:
#         image = image_array

#     # Step 1: Enhance contrast using CLAHE
#     clahe = cv2.createCLAHE(clipLimit=2.5, tileGridSize=(8, 8))
#     enhanced_image = clahe.apply(image)
    
#     # Step 2: Smooth the image
#     smoothed_image = cv2.GaussianBlur(enhanced_image, (5, 5), 0)
    
#     # Step 3: Detect edges using dynamic Canny thresholds
#     median_intensity = np.median(smoothed_image)
#     lower_threshold = int(max(0, (0.5 - 0.4) * median_intensity))
#     upper_threshold = int(min(255, (0.5+ 0.4) * median_intensity))
#     edges = cv2.Canny(smoothed_image, lower_threshold, upper_threshold)
    
#     # Step 4: Dilate edges with a smaller kernel
#     kernel = np.ones((2, 2), np.uint8)
#     dilated_edges = cv2.dilate(edges, kernel, iterations=2)
    
#     # Step 5: Fill gaps using morphological closing
#     closed_edges = cv2.morphologyEx(dilated_edges, cv2.MORPH_CLOSE, kernel)
    
#     # Step 6: Find the largest contour
#     mask = np.zeros_like(image)
#     contours, _ = cv2.findContours(closed_edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     if contours:
#         largest_contour = max(contours, key=cv2.contourArea)
#         cv2.drawContours(mask, [largest_contour], -1, 255, thickness=-1)
    
#     return mask


# def extract_segmented_inner_shape(image, mask):
#     """
#     Extracts the segmented inner shape by applying the refined mask to the original image.
#     """
#     # Refine the mask using morphological operations
#     kernel = np.ones((3, 3), np.uint8)
#     refined_mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=3)
#     refined_mask = cv2.morphologyEx(refined_mask, cv2.MORPH_CLOSE, kernel, iterations=3)
    
#     # Apply the refined mask to the image
#     segmented_inner = np.zeros_like(image)
#     segmented_inner[refined_mask == 255] = image[refined_mask == 255]
    
#     return segmented_inner


# # # Input and output directories
# input_dir ="C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\Al_Z27_01"
# mask_output_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\stam_mask"
# segmented_inner_output_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\stam_seg"
# os.makedirs(mask_output_dir, exist_ok=True)
# os.makedirs(segmented_inner_output_dir, exist_ok=True)

# # Process images
# for filename in os.listdir(input_dir):
#     if filename.endswith('.png'):
#         image_path = os.path.join(input_dir, filename)
#         print(f"Processing {filename}...")

#         img = cv2.imread(image_path)

#         # Extract the mask
#         mask = extract_mask_from_array(img)
#         largest_contour = get_largest_contour(mask, min_area=20000)  # Increased minimum area filter

#         # Determine the center and radius for the circular region
#         center = (mask.shape[1] // 2, mask.shape[0] // 2)
#         if largest_contour is not None:
#             _, enclosing_radius = cv2.minEnclosingCircle(largest_contour)
#             radius = int(enclosing_radius * 0.85) # Shrink further to exclude fringe areas, 0.92 for EBM6, 0.85 for EBM9 , 0.80 for AI
#         else:
#             radius = min(center[0], center[1]) - 15

#         # Refine the mask
#         refined_mask = refine_mask(mask, largest_contour, center, radius)

#         # Save the refined mask
#         mask_path = os.path.join(mask_output_dir, f"{os.path.splitext(filename)[0]}_mask.png")
#         cv2.imwrite(mask_path, refined_mask)

#         # Extract and save the segmented inner shape
#         segmented_inner = extract_segmented_inner_shape(img, refined_mask)
#         segmented_inner_path = os.path.join(segmented_inner_output_dir, f"{os.path.splitext(filename)[0]}_segmented_inner.png")
#         cv2.imwrite(segmented_inner_path, segmented_inner)

#         print(f"Completed processing for {filename}")

#=======================================================================================================================================================
# for SLM and EBM6 images
import os
import cv2
import numpy as np

def get_contour(mask: np.ndarray):
    """
    Extracts the largest contour from the given binary mask.
    """
    ret, thresh = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        return largest_contour
    return None

def refine_mask(mask: np.ndarray, contour: np.ndarray, center: tuple, radius: int):
    """
    Refines the mask by keeping only the region inside the largest contour
    and applying a circular constraint.
    """
    refined_mask = np.zeros_like(mask)
    if contour is not None:
        # Draw the largest contour
        cv2.drawContours(refined_mask, [contour], -1, 255, thickness=-1)
        # Create a circular mask to constrain the region
        circular_mask = np.zeros_like(mask)
        cv2.circle(circular_mask, center, radius, 255, thickness=-1)
        # Combine the two masks
        refined_mask = cv2.bitwise_and(refined_mask, circular_mask)
    return refined_mask

def extract_mask_from_array(image_array):
    """
    Extracts the mask for the external contour from an image array using a CV-based approach.
    """
    if len(image_array.shape) == 3:
        image = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
    else:
        image = image_array

    # Step 1: Enhance contrast using CLAHE
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(image)
    
    # Step 2: Smooth the image
    smoothed_image = cv2.GaussianBlur(enhanced_image, (5, 5), 0)
    
    # Step 3: Detect edges using Canny
    edges = cv2.Canny(smoothed_image, 50, 150)
    
    # Step 4: Dilate edges with smaller kernel and more iterations
    kernel = np.ones((2, 2), np.uint8)  # smaller kernel size
    dilated_edges = cv2.dilate(edges, kernel, iterations=1)  # increase iterations
    
    # Step 5: Fill gaps using morphological closing
    closed_edges = cv2.morphologyEx(dilated_edges, cv2.MORPH_CLOSE, kernel)
    
    # Step 6: Find the largest contour
    mask = np.zeros_like(image)
    contours, _ = cv2.findContours(closed_edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        cv2.drawContours(mask, [largest_contour], -1, 255, thickness=-1)
    
    return mask


def extract_segmented_inner_shape(image, mask):
    """
    Extracts the segmented inner shape by applying the mask to the original image.
    """
    # Perform morphological operations to further refine the mask
    kernel = np.ones((2, 2), np.uint8)
    refined_mask = cv2.erode(mask, kernel, iterations=1)  # Increased erosion to remove more unwanted areas
    refined_mask = cv2.dilate(refined_mask, kernel, iterations=3)  # Dilation to strengthen the relevant area
    
    # Apply the refined mask to the image
    segmented_inner = np.zeros_like(image)
    segmented_inner[refined_mask == 255] = image[refined_mask == 255]
    
    # Optional: Apply Gaussian blur to smooth the boundaries of the segmented region
    segmented_inner = cv2.GaussianBlur(segmented_inner, (5, 5), 0)
    
    return segmented_inner

# Input and output directories
input_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-TI-6AL-4V-SEM\\P1"
mask_output_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-P1-masks"
segmented_inner_output_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-P1-segmented_inner_Shape"
os.makedirs(mask_output_dir, exist_ok=True)
os.makedirs(segmented_inner_output_dir, exist_ok=True)

# Process images
for filename in os.listdir(input_dir):
    if filename.endswith('.png'):
        image_path = os.path.join(input_dir, filename)
        print(f"Processing {filename}...")

        img = cv2.imread(image_path)

        # Extract the mask
        mask = extract_mask_from_array(img)
        largest_contour = get_contour(mask)

        # Determine the center and radius for the circular region
        center = (mask.shape[1] // 2, mask.shape[0] // 2)
        radius = min(center[0], center[1]) - 10  # Adjust the radius to fit your needs

        # Refine the mask
        refined_mask = refine_mask(mask, largest_contour, center, radius)

        # Save the refined mask
        mask_path = os.path.join(mask_output_dir, f"{os.path.splitext(filename)[0]}_mask.png")
        cv2.imwrite(mask_path, refined_mask)

        # Extract and save the segmented inner shape
        segmented_inner = extract_segmented_inner_shape(img, refined_mask)
        segmented_inner_path = os.path.join(segmented_inner_output_dir, f"{os.path.splitext(filename)[0]}_segmented_inner.png")
        cv2.imwrite(segmented_inner_path, segmented_inner)

        print(f"Completed processing for {filename}")
# Out:
# Processing F5_C_01.png...
# Completed processing for F5_C_01.png
# Processing F5_N_01.png...
# Completed processing for F5_N_01.png
# Processing P1MF13_C_01.png...
# Completed processing for P1MF13_C_01.png
# Processing P1MF13_N_01.png...
# Completed processing for P1MF13_N_01.png
# Processing P1MF15_C_01.png...
# Completed processing for P1MF15_C_01.png
# Processing P1MF15_N_01.png...
# Completed processing for P1MF15_N_01.png
# Processing P1MF16_N_01.png...
# Completed processing for P1MF16_N_01.png
# Processing P1MF17_C_01.png...
# Completed processing for P1MF17_C_01.png
# Processing P1MF17_N_01.png...
# Completed processing for P1MF17_N_01.png
# Processing P1MF18_N_01.png...
# Completed processing for P1MF18_N_01.png
# Processing P1MF19_C_01 (1).png...
# Completed processing for P1MF19_C_01 (1).png
# Processing P1MF19_C_01.png...
# Completed processing for P1MF19_C_01.png
# Processing P1MF19_N_01.png...
# Completed processing for P1MF19_N_01.png
# Processing P1MF1_C_01.png...
# Completed processing for P1MF1_C_01.png
# Processing P1MF1_N_01.png...
# Completed processing for P1MF1_N_01.png
# Processing P1MF20_C_01.png...
# Completed processing for P1MF20_C_01.png
# Processing P1MF20_N_01.png...
# Completed processing for P1MF20_N_01.png
# Processing P1MF2_C_01.png...
# Completed processing for P1MF2_C_01.png
# Processing P1MF2_N_01.png...
# Completed processing for P1MF2_N_01.png
# Processing P1MF3_C_01.png...
# Completed processing for P1MF3_C_01.png
# Processing P1MF3_N_01.png...
# Completed processing for P1MF3_N_01.png
# Processing P1MF4_C_01.png...
# Completed processing for P1MF4_C_01.png
# Processing P1MF4_N_01.png...
# Completed processing for P1MF4_N_01.png
# Processing P1MF5_C_01.png...
# Completed processing for P1MF5_C_01.png
# Processing P1MF5_N_01.png...
# Completed processing for P1MF5_N_01.png
# Processing P1MF6_C_01.png...
# Completed processing for P1MF6_C_01.png
# Processing P1MF6_N_01.png...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 379
#     377 segmented_inner = extract_segmented_inner_shape(img, refined_mask)
#     378 segmented_inner_path = os.path.join(segmented_inner_output_dir, f"{os.path.splitext(filename)[0]}_segmented_inner.png")
# --> 379 cv2.imwrite(segmented_inner_path, segmented_inner)
#     381 print(f"Completed processing for {filename}")
#
# KeyboardInterrupt:

# %%
def get_heatmap(img, contour):
    img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Create a mask with the contour
    mask = np.zeros(img_grey.shape, np.uint8)
    cv2.drawContours(mask, [contour], -1, (255, 255, 255), -1, cv2.LINE_AA)
    
    # Create an output image where the mask is applied
    out = np.zeros_like(img)
    out[mask == 255] = img[mask == 255]
    img_color = cv2.cvtColor(out, cv2.COLOR_BGR2RGB)
    
    # Process for heatmap generation
    img_grey = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(img_grey, (13, 13), 0)
    
    sobelx = cv2.Sobel(blur, cv2.CV_8U, 1, 0, ksize=5)
    sobely = cv2.Sobel(blur, cv2.CV_8U, 0, 1, ksize=5)
    
    sobel_magnitude = np.sqrt(sobelx**2 + sobely**2)
    sobel_magnitude = sobel_magnitude / sobel_magnitude.max() * 255
    sobel_magnitude = np.uint8(sobel_magnitude)
    
    # Define window parameters for localized averaging
    window_size = 201
    window_step = 10
    
    heat_map_sobel = np.zeros(sobel_magnitude.shape, dtype=np.uint8)
    
    # Pad the images
    sobel_c = np.pad(sobel_magnitude, int((window_size-1)/2), mode='constant', constant_values=0)
    mask_metal_c = np.pad(mask, int((window_size-1)/2), mode='constant', constant_values=0)
    
    for y in range(0, sobel_c.shape[0], window_step):
        for x in range(0, sobel_c.shape[1], window_step):
            window = sobel_c[y:y+window_size, x:x+window_size]
            mask_metal_window = mask_metal_c[y:y+window_size, x:x+window_size] / 255
            if mask_metal_window.sum() == 0 or mask_metal_window[int((window_size - 1) / 2), int((window_size - 1) / 2)] == 0:
                heat_map_sobel[y:y+window_step, x:x+window_step] = 0
            else:
                heat_map_sobel[y:y+window_step, x:x+window_step] = np.sum(window) / mask_metal_window.sum()
    
    heat_map_sobel = cv2.equalizeHist(heat_map_sobel)
    heat_map_color_sobel = cv2.applyColorMap(heat_map_sobel, cv2.COLORMAP_JET)
    
    # Replace background color (set areas outside the mask to a specific color)
    background_color = (0, 0, 0)  # Black (can be adjusted to any color)
    heat_map_color_sobel[mask == 0] = background_color  # Set the background color
    
    return heat_map_color_sobel

# %%
def process_heatmaps(input_dir, mask_dir, output_dir):
    """
    Processes all images in a directory to generate heatmaps based on Sobel filtering.

    Args:
        input_dir (str): Directory containing input images.
        mask_dir (str): Directory containing saved masks.
        output_dir (str): Directory to save generated heatmaps.
    """
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):  # Process only PNG files
            image_path = os.path.join(input_dir, filename)
            mask_path = os.path.join(mask_dir, f"{os.path.splitext(filename)[0]}_mask.png")

            # Ensure mask exists
            if not os.path.exists(mask_path):
                print(f"Mask not found for {filename}, skipping.")
                continue

            # Load the image and mask
            img = cv2.imread(image_path)
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

            # Get the contour from the saved mask
            ext_contour = get_largest_contour(mask)

            if ext_contour is None:
                print(f"No valid contour found for {filename}, skipping.")
                continue

            # Generate the heatmap
            heatmap_img = get_heatmap(img, ext_contour)

            # Save the heatmap
            heatmap_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_heatmap.png")
            cv2.imwrite(heatmap_path, heatmap_img)
            print(f"Heatmap saved: {heatmap_path}")

# Specify input and output directories
input_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-TI-6AL-4V-SEM\\P1"
mask_dir =  "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-P1-masks"
output_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-P1-heatmaps"

# Process all images to generate heatmaps
process_heatmaps(input_dir, mask_dir, output_dir)
# Out:
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\F5_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\F5_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF13_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF13_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF15_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF15_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF16_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF17_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF17_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF18_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF19_C_01 (1)_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF19_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF19_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF1_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF1_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF20_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF20_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF2_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF2_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF3_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF3_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF4_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF4_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF5_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF5_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF6_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF6_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF7_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF7_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF8_C_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1MF8_N_01_heatmap.png
# Heatmap saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-heatmaps\P1NF16_C_01_heatmap.png

# %%
import os
import cv2
import numpy as np

def combine_images_with_labels(original, segmented_inner, mask, heatmap, filename, output_path):
    """
    Combines four images (original, segmented inner shape, mask, heatmap) into one image with the filename at the top in red.
    Additionally, it adds labels below each image (Original Image, Segmented Inner Shape, Mask, Heatmap).

    Args:
        original (ndarray): Original image.
        segmented_inner (ndarray): Segmented inner shape image.
        mask (ndarray): Mask image.
        heatmap (ndarray): Heatmap image.
        filename (str): Filename of the original image (used as a label).
        output_path (str): Path to save the combined image.
    """
    # Resize all images to the same dimensions
    target_size = (512, 512)  # Adjust size as needed
    original = cv2.resize(original, target_size)
    segmented_inner = cv2.resize(segmented_inner, target_size)
    mask = cv2.resize(mask, target_size)
    heatmap = cv2.resize(heatmap, target_size)

    # Convert grayscale images to BGR for consistent visualization
    if len(segmented_inner.shape) == 2:
        segmented_inner = cv2.cvtColor(segmented_inner, cv2.COLOR_GRAY2BGR)
    if len(mask.shape) == 2:
        mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

    # Create a black image for the filename label
    label_height = 50
    label_image = np.zeros((label_height, target_size[0], 3), dtype=np.uint8)

    # Add the filename to the black image (filename in red)
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1
    thickness = 2
    red_color = (0, 0, 255)  # Red text (BGR format)

    def add_label(text, color):
        label = label_image.copy()
        text_size = cv2.getTextSize(text, font, font_scale, thickness)[0]
        text_x = (label.shape[1] - text_size[0]) // 2
        text_y = (label.shape[0] + text_size[1]) // 2
        cv2.putText(label, text, (text_x, text_y), font, font_scale, color, thickness, cv2.LINE_AA)
        return label

    # Filename label with red text
    filename_label = add_label(f"{os.path.splitext(filename)[0]}", red_color)

    # Resize the filename label to match the width of the combined image (1024)
    filename_label_resized = cv2.resize(filename_label, (original.shape[1] * 2, label_height))

    # Create labels for the images (e.g., "Original Image", "Segmented Inner Shape", etc.) in white color
    white_color = (255, 255, 255)  # White text for other labels
    original_label = add_label("Original Image", white_color)
    segmented_inner_label = add_label("Segmented Inner Shape", white_color)
    mask_label = add_label("Mask", white_color)
    heatmap_label = add_label("Heatmap", white_color)

    # Combine labels and images
    original_combined = np.vstack([original_label, original])
    segmented_inner_combined = np.vstack([segmented_inner_label, segmented_inner])
    mask_combined = np.vstack([mask_label, mask])
    heatmap_combined = np.vstack([heatmap_label, heatmap])

    # Stack images in a 2x2 grid
    top_row = np.hstack([original_combined, segmented_inner_combined])
    bottom_row = np.hstack([mask_combined, heatmap_combined])
    combined = np.vstack([top_row, bottom_row])

    # Add the filename label at the top of the final combined image
    combined_with_filename = np.vstack([filename_label_resized, combined])

    # Save the combined image
    cv2.imwrite(output_path, combined_with_filename)
    print(f"Combined image saved: {output_path}")

# Directory paths
input_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-TI-6AL-4V-SEM\\P1"
segmented_inner_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-P1-segmented_inner_shape"
mask_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-P1-masks"
heatmap_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-P1-heatmaps"
output_dir = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\\SLM-P1-Results"

# Create output directory
os.makedirs(output_dir, exist_ok=True)

# Process each image
for filename in os.listdir(input_dir):
    if filename.endswith('.png'):  # Process only PNG files
        original_path = os.path.join(input_dir, filename)
        segmented_inner_path = os.path.join(segmented_inner_dir, f"{os.path.splitext(filename)[0]}_segmented_inner.png")
        mask_path = os.path.join(mask_dir, f"{os.path.splitext(filename)[0]}_mask.png")
        heatmap_path = os.path.join(heatmap_dir, f"{os.path.splitext(filename)[0]}_heatmap.png")

        # Check if all required files exist
        if not (os.path.exists(original_path) and os.path.exists(segmented_inner_path) and 
                os.path.exists(mask_path) and os.path.exists(heatmap_path)):
            print(f"Missing files for {filename}, skipping.")
            continue

        # Load images
        original = cv2.imread(original_path)
        segmented_inner = cv2.imread(segmented_inner_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        heatmap = cv2.imread(heatmap_path)

        # Combine images and save the result
        output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_combined.png")
        combine_images_with_labels(original, segmented_inner, mask, heatmap, filename, output_path)
# Out:
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\F5_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\F5_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF13_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF13_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF15_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF15_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF16_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF17_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF17_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF18_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF19_C_01 (1)_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF19_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF19_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF1_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF1_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF20_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF20_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF2_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF2_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF3_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF3_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF4_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF4_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF5_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF5_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF6_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF6_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF7_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF7_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF8_C_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1MF8_N_01_combined.png
# Combined image saved: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\SLM-P1-Results\P1NF16_C_01_combined.png

# %%
 #Step: Detect Crack Zone
import cv2
import numpy as np
import os

# === Directory Configuration ===
base_path = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main"
heatmap_folder = os.path.join(base_path, "SLM-P1-heatmaps")
highlighted_output_folder = os.path.join(base_path, "SLM-P1-CrackZone")
os.makedirs(highlighted_output_folder, exist_ok=True)

# === HSV Color Ranges ===
color_ranges = {
    "dark_red": [([0, 200, 100], [10, 255, 180]), ([160, 200, 100], [180, 255, 180])],
    "red": [([0, 180, 180], [10, 255, 255]), ([160, 180, 180], [180, 255, 255])],
    "orange": [([10, 100, 100], [25, 255, 255])]
}

kernel = np.ones((5, 5), np.uint8)

# === Process Heatmaps ===
for filename in os.listdir(heatmap_folder):
    if not filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        continue

    filepath = os.path.join(heatmap_folder, filename)
    image = cv2.imread(filepath)
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Build red mask
    red_mask = np.zeros(hsv.shape[:2], dtype=np.uint8)
    for lower, upper in color_ranges["dark_red"] + color_ranges["red"]:
        red_mask |= cv2.inRange(hsv, np.array(lower), np.array(upper))
    red_mask = cv2.morphologyEx(red_mask, cv2.MORPH_OPEN, kernel)
    red_mask = cv2.morphologyEx(red_mask, cv2.MORPH_CLOSE, kernel)

    # Build orange mask
    orange_mask = np.zeros(hsv.shape[:2], dtype=np.uint8)
    for lower, upper in color_ranges["orange"]:
        orange_mask |= cv2.inRange(hsv, np.array(lower), np.array(upper))
    orange_mask = cv2.morphologyEx(orange_mask, cv2.MORPH_OPEN, kernel)
    orange_mask = cv2.morphologyEx(orange_mask, cv2.MORPH_CLOSE, kernel)

    # Find contours
    contours_red, _ = cv2.findContours(red_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours_orange, _ = cv2.findContours(orange_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    largest_contour = None
    max_area = 0

    for o in contours_orange:
        if cv2.contourArea(o) < 50:
            continue

        M = cv2.moments(o)
        if M["m00"] == 0:
            continue
        cx = int(M["m10"] / M["m00"])
        cy = int(M["m01"] / M["m00"])

        for r in contours_red:
            if cv2.pointPolygonTest(r, (cx, cy), False) >= 0:
                area = cv2.contourArea(o)
                if area > max_area:
                    max_area = area
                    largest_contour = o
                break

    # === Save Highlighted Heatmap
    if largest_contour is not None:
        overlay = image.copy()
        (x, y), radius = cv2.minEnclosingCircle(largest_contour)
        center = (int(x), int(y))
        radius = int(radius)

        # Draw circles
        cv2.circle(overlay, center, radius + 6, (0, 0, 0), 4)
        cv2.circle(overlay, center, radius, (0, 255, 255), 4)

        # Label
        text = "Internal Orange Zone"
        text_position = (center[0] - radius, center[1] - radius - 10)
        cv2.putText(overlay, text, text_position, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

        # Blend overlay
        final_result = cv2.addWeighted(overlay, 0.75, image, 0.25, 0)

        # Save only the highlighted heatmap
        output_path = os.path.join(highlighted_output_folder, f"{os.path.splitext(filename)[0]}_highlighted.png")
        cv2.imwrite(output_path, final_result)

        print(f"✔ Saved highlighted crack zone for {filename}")

print("✅ Done: Highlighted crack zones saved for all heatmaps.")
#==========================================================================================================

# ---------------------------------------------------
# Step: Detect Crack Zone Using Convex Hull (for some images)
# ---------------------------------------------------

# import cv2
# import numpy as np
# import os
# from scipy.spatial import ConvexHull

# # === Directory Configuration ===
# base_path = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main"
# heatmap_folder = os.path.join(base_path, "SLM-Problamtic-HM")
# highlighted_output_folder = os.path.join(base_path, "SLM-P1-CrackZone-part2")
# os.makedirs(highlighted_output_folder, exist_ok=True)

# # === Process Each .png Heatmap ===
# for image_name in os.listdir(input_folder):
#     if not image_name.lower().endswith(".png"):
#         continue

#     input_path = os.path.join(input_folder, image_name)
#     output_path = os.path.join(highlighted_output_folder, image_name.replace("_heatmap", "_convex_highlighted"))

#     # Load image and convert to HSV
#     img = cv2.imread(input_path)
#     hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

#     # === Warm Colors (Red to Yellow) Mask ===
#     lower_red1 = np.array([0, 70, 50])
#     upper_red1 = np.array([10, 255, 255])
#     lower_red2 = np.array([160, 70, 50])
#     upper_red2 = np.array([180, 255, 255])
#     lower_orange = np.array([11, 70, 50])
#     upper_orange = np.array([35, 255, 255])

#     mask_red = cv2.bitwise_or(
#         cv2.inRange(hsv, lower_red1, upper_red1),
#         cv2.inRange(hsv, lower_red2, upper_red2)
#     )
#     mask_orange = cv2.inRange(hsv, lower_orange, upper_orange)
#     heat_mask = cv2.bitwise_or(mask_red, mask_orange)

#     # Morphological Smoothing
#     kernel = np.ones((9, 9), np.uint8)
#     heat_mask = cv2.morphologyEx(heat_mask, cv2.MORPH_CLOSE, kernel)
#     heat_mask = cv2.morphologyEx(heat_mask, cv2.MORPH_OPEN, kernel)

#     # === Find and Draw Convex Hull ===
#     contours, _ = cv2.findContours(heat_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

#     if contours:
#         largest = max(contours, key=cv2.contourArea)

#         # Extract contour points
#         contour_points = largest.reshape(-1, 2)

#         # Apply Convex Hull
#         hull = ConvexHull(contour_points)
#         hull_points = contour_points[hull.vertices]

#         # Draw the convex hull in WHITE
#         cv2.polylines(img, [hull_points], isClosed=True, color=(255, 255, 255), thickness=25)

#         # Save the final image with white contour
#         cv2.imwrite(output_path, img)
#         print(f"✔ Saved convex hull highlight for: {image_name}")

#     else:
#         print(f"⚠ No warm contours found in: {image_name}")

# print("✅ Done: Highlighted crack zones (convex hull) saved for all selected heatmaps.")
# Out:
# ✔ Saved highlighted crack zone for F5_C_01_heatmap.png
# ✔ Saved highlighted crack zone for F5_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF13_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF13_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF15_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF15_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF16_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF17_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF17_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF18_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF19_C_01 (1)_heatmap.png
# ✔ Saved highlighted crack zone for P1MF19_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF19_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF1_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF1_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF20_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF20_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF2_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF2_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF3_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF3_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF4_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF4_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF5_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF5_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF6_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF6_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF7_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF7_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF8_C_01_heatmap.png
# ✔ Saved highlighted crack zone for P1MF8_N_01_heatmap.png
# ✔ Saved highlighted crack zone for P1NF16_C_01_heatmap.png
# ✅ Done: Highlighted crack zones saved for all heatmaps.

# %%
# ---------------------------------------------------
# Step: Combine Available Original, Heatmap, and Crack Zone Highlight WITH Sample Name on Top
# ---------------------------------------------------

import cv2
import numpy as np
import os

# === Directory Configuration ===
base_path = "C:\\Users\\shifa\\final project\\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main"

original_folder = os.path.join(base_path, "P3")  # Original images
heatmap_folder = os.path.join(base_path, "SLM-P3-heatmaps")  # Heatmaps
crackzone_folder = os.path.join(base_path, "SLM-P3-CrackZone")  # Crackzone highlights

combined_output_folder = os.path.join(base_path, "SLM-P3_CrackZone_Results")
os.makedirs(combined_output_folder, exist_ok=True)

# === Text Parameters ===
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 1.2
thickness = 2
text_color = (0, 0, 0)  # Black text

# === Process Each Image in Heatmap Folder ===
for filename in os.listdir(heatmap_folder):
    if not filename.lower().endswith('.png'):
        continue

    # Handle base name carefully: just remove '_heatmap' and nothing else
    name_base = filename.replace('_heatmap', '')  # Keep (1) if it exists

    # Build paths
    original_path = os.path.join(original_folder, name_base)
    heatmap_path = os.path.join(heatmap_folder, filename)
    crackzone_path = os.path.join(crackzone_folder, filename.replace('_heatmap', '_heatmap_highlighted'))

    images = []
    titles = []

    # Try loading original image
    print(f"🔍 Looking for original: {original_path}")  # DEBUG
    if os.path.exists(original_path):
        original_img = cv2.imread(original_path)
        original_img = cv2.resize(original_img, (512, 512))
        images.append(original_img)
        titles.append("Original Image")
    else:
        print(f"⚠ Original NOT found: {original_path}")

    # Try loading heatmap
    if os.path.exists(heatmap_path):
        heatmap_img = cv2.imread(heatmap_path)
        heatmap_img = cv2.resize(heatmap_img, (512, 512))
        images.append(heatmap_img)
        titles.append("Heatmap")
    else:
        print(f"⚠ Heatmap NOT found: {heatmap_path}")

    # Try loading crackzone
    if os.path.exists(crackzone_path):
        crackzone_img = cv2.imread(crackzone_path)
        crackzone_img = cv2.resize(crackzone_img, (512, 512))
        images.append(crackzone_img)
        titles.append("Heatmap + Crack Zone")
    else:
        print(f"⚠ Crackzone NOT found: {crackzone_path}")

    # If we have at least 1 image, combine and save
    if images:
        # Add titles above each image
        combined_images = []
        for img, title in zip(images, titles):
            title_bar = np.ones((50, img.shape[1], 3), dtype=np.uint8) * 255  # White bar
            cv2.putText(title_bar, title, (30, 35), font, font_scale, text_color, thickness, cv2.LINE_AA)
            full_img = np.vstack((title_bar, img))
            combined_images.append(full_img)

        # Concatenate horizontally
        combined_horizontal = np.hstack(combined_images)

        # === Add full sample name at the very top ===
        total_width = combined_horizontal.shape[1]
        sample_title_bar = np.ones((80, total_width, 3), dtype=np.uint8) * 255  # Bigger white bar for sample name
        clean_name = name_base.replace(".png", "")
        cv2.putText(sample_title_bar, f"Sample: {clean_name}", (30, 60), font, 1.5, text_color, 3, cv2.LINE_AA)

        final_combined = np.vstack((sample_title_bar, combined_horizontal))

        # Save
        save_name = name_base.replace(".png", "_combined.png")  # Clean final save name
        output_path = os.path.join(combined_output_folder, save_name)
        cv2.imwrite(output_path, final_combined)
        print(f"✅ Saved combined image for {name_base}")
    else:
        print(f"⚠ No images found for {name_base}, completely skipped.")

print("🎉 Done combining available images!")
# Out:
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF10_01.png
# ✅ Saved combined image for P3mF10_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF10_N_01.png
# ✅ Saved combined image for P3mF10_N_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF12_01.png
# ✅ Saved combined image for P3mF12_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF12_N_01.png
# ✅ Saved combined image for P3mF12_N_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF16_01.png
# ✅ Saved combined image for P3MF16_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF16_name_01.png
# ✅ Saved combined image for P3MF16_name_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF18_01.png
# ✅ Saved combined image for P3MF18_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF18_name_01.png
# ✅ Saved combined image for P3MF18_name_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF20_C_01.png
# ✅ Saved combined image for P3MF20_C_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF20_N_01.png
# ✅ Saved combined image for P3MF20_N_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF2_01.png
# ✅ Saved combined image for P3MF2_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF2_N_01.png
# ✅ Saved combined image for P3mF2_N_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF4_01.png
# ✅ Saved combined image for P3mF4_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF4_N_01.png
# ✅ Saved combined image for P3mF4_N_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF6_01.png
# ✅ Saved combined image for P3mF6_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3mF6_N_01.png
# ✅ Saved combined image for P3mF6_N_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF8_01.png
# ✅ Saved combined image for P3MF8_01.png
# 🔍 Looking for original: C:\Users\shifa\final project\Final_Project_Fractographic_Failure_Analysis_with_CV_in_AM-main\P3\P3MF8_name_01.png
# ✅ Saved combined image for P3MF8_name_01.png
# 🎉 Done combining available images!
